# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
covid19=pd.read_csv('covid19.csv')

# %%
covid19
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
covid19.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
covid19.groupby('Country/Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered  Active  New cases  \
# Country/Region
# Afghanistan             36263    1269      25198    9796        106
# Albania                  4880     144       2745    1991        117
# Algeria                 27973    1163      18837    7973        616
# Andorra                   907      52        803      52         10
# Angola                    950      41        242     667         18
# ...                       ...     ...        ...     ...        ...
# West Bank and Gaza      10621      78       3752    6791        152
# Western Sahara             10       1          8       1          0
# Yemen                    1691     483        833     375         10
# Zambia                   4552     140       2815    1597         71
# Zimbabwe                 2704      36        542    2126        192
#
#                     New deaths  New recovered  Deaths / 100 Cases  \
# Country/Region
# ...

# %%
plt.figure(figsize=(15,20))
sns.heatmap(covid19.isnull())
plt.show()

# %% [markdown]
# ### Finding each of the cases

# %%
covid19.groupby('Country/Region')['Confirmed'].sum()
# Out:
# Country/Region
# Afghanistan           36263
# Albania                4880
# Algeria               27973
# Andorra                 907
# Angola                  950
#                       ...
# West Bank and Gaza    10621
# Western Sahara           10
# Yemen                  1691
# Zambia                 4552
# Zimbabwe               2704
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid19.groupby('Country/Region')['Confirmed','Deaths'].sum()
# Out:
# C:\Users\Faraz\AppData\Local\Temp\ipykernel_5888\2838944235.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   covid19.groupby('Country/Region')['Confirmed','Deaths'].sum()
#                     Confirmed  Deaths
# Country/Region
# Afghanistan             36263    1269
# Albania                  4880     144
# Algeria                 27973    1163
# Andorra                   907      52
# Angola                    950      41
# ...                       ...     ...
# West Bank and Gaza      10621      78
# Western Sahara             10       1
# Yemen                    1691     483
# Zambia                   4552     140
# Zimbabwe                 2704      36
#
# [187 rows x 2 columns]

# %%
covid19.groupby('Country/Region')['Confirmed','Deaths','Recovered'].sum()
# Out:
# C:\Users\Faraz\AppData\Local\Temp\ipykernel_5888\2769919298.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   covid19.groupby('Country/Region')['Confirmed','Deaths','Recovered'].sum()
#                     Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan             36263    1269      25198
# Albania                  4880     144       2745
# Algeria                 27973    1163      18837
# Andorra                   907      52        803
# Angola                    950      41        242
# ...                       ...     ...        ...
# West Bank and Gaza      10621      78       3752
# Western Sahara             10       1          8
# Yemen                    1691     483        833
# Zambia                   4552     140       2815
# Zimbabwe                 2704      36        542
#
# [187 rows x 3 columns]

# %%
#Maximum confirm cases of covid 19
covid19.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Country/Region
# US                       4290259
# Brazil                   2442375
# India                    1480073
# Russia                    816680
# South Africa              452529
#                           ...
# Dominica                      18
# Saint Kitts and Nevis         17
# Greenland                     14
# Holy See                      12
# Western Sahara                10
# Name: Confirmed, Length: 187, dtype: int64

# %%
#Minimum confirm cases of Covid 19 
covid19.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=True)
# Out:
# Country/Region
# Western Sahara                10
# Holy See                      12
# Greenland                     14
# Saint Kitts and Nevis         17
# Dominica                      18
#                           ...
# South Africa              452529
# Russia                    816680
# India                    1480073
# Brazil                   2442375
# US                       4290259
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid19[covid19['Country/Region']=='Pakistan','Russia']
# Out:
# Empty DataFrame
# Columns: [Country/Region, Confirmed, Deaths, Recovered, Active, New cases, New deaths, New recovered, Deaths / 100 Cases, Recovered / 100 Cases, Deaths / 100 Recovered, Confirmed last week, 1 week change, 1 week % increase, WHO Region]
# Index: []

# %%
covid19.groupby('Country/Region').Deaths.sum().sort_values(ascending=False)
# Out:
# Country/Region
# US                148011
# Brazil             87618
# United Kingdom     45844
# Mexico             44022
# Italy              35112
#                    ...
# Laos                   0
# Greenland              0
# Cambodia               0
# Grenada                0
# Mongolia               0
# Name: Deaths, Length: 187, dtype: int64

# %%
covid19.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=False).head(25)
# Out:
# Country/Region
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Pakistan           274289
# Spain              272421
# Saudi Arabia       268934
# Colombia           257101
# Italy              246286
# Turkey             227019
# Bangladesh         226225
# France             220352
# Germany            207112
# Argentina          167416
# Canada             116458
# Iraq               112585
# Qatar              109597
# Indonesia          100303
# Egypt               92482
# Name: Confirmed, dtype: int64

# %%
covid19.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=True).head(25)
# Out:
# Country/Region
# Western Sahara                       10
# Holy See                             12
# Greenland                            14
# Saint Kitts and Nevis                17
# Dominica                             18
# Laos                                 20
# Grenada                              23
# Timor-Leste                          24
# Saint Lucia                          24
# Fiji                                 27
# Belize                               48
# Saint Vincent and the Grenadines     52
# Papua New Guinea                     62
# Antigua and Barbuda                  86
# Liechtenstein                        86
# Bhutan                               99
# Barbados                            110
# Seychelles                          114
# Monaco                              116
# Brunei                              141
# Trinidad and Tobago                 148
# Cambodia                            226
# Eritrea                             265
# ...

# %%
covid19[covid19['Confirmed']<1000]
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered  Active  \
# 3                             Andorra        907      52        803      52
# 4                              Angola        950      41        242     667
# 5                 Antigua and Barbuda         86       3         65      18
# 11                            Bahamas        382      11         91     280
# 14                           Barbados        110       7         94       9
# 17                             Belize         48       2         26      20
# 19                             Bhutan         99       0         86      13
# 22                           Botswana        739       2         63     674
# 24                             Brunei        141       3        138       0
# 27                              Burma        350       6        292      52
# 28                            Burundi        378       1        301      76
# ...

# %%
covid19=covid19[~(covid19['Confirmed']<1000)]

# %%
covid19
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# ..                  ...        ...     ...        ...     ...        ...
# 180           Venezuela      15988     146       9959    5883        525
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
covid19['New recovered']=covid19['New recovered'].apply(lambda x:x-12)
# Out:
# C:\Users\Faraz\AppData\Local\Temp\ipykernel_5888\1579825137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid19['New recovered']=covid19['New recovered'].apply(lambda x:x-12)

# %%
covid19['New recovered']
# Out:
# 0        20
# 1        65
# 2       751
# 6      2059
# 7       189
#        ...
# 180     215
# 182       2
# 184      38
# 185     467
# 186      26
# Name: New recovered, Length: 142, dtype: int64

# %%
df=covid19.iloc[0:132,0:3].tail(50)

# %%
plt.figure(figsize=(50,75))
df.hist()
plt.show()

# %%
df2=covid19['Confirmed'].tail(10)

# %%
import numpy as np

# %%
ind=np.arange(10)

# %%
df3=covid19['Country/Region'].tail(10)

# %%
plt.figure(figsize=(20,10))
plt.bar(ind,df2)
plt.xticks(ind,df3)
plt.xlabel('Countries',size=30)
plt.ylabel('Confirmed Cases',size=30)
plt.title('Countries Which have Ratio of Confirmed Cases',size=40)
plt.show()
